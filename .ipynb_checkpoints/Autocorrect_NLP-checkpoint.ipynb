# %% [markdown]
# # Autocorrect

# %% [markdown]
# <a name='0'></a>
# ## 0. Overview
#
# You use autocorrect every day on your cell phone and computer. We will explore what really goes on behind the scenes. Of course, the model we are about to implement is not identical to the one used in our phone, but it is still quite good.
#
# - Get a word count given a corpus
# - Get a word probability in the corpus
# - Manipulate strings
# - Filter strings
# - Implement Minimum edit distance to compare strings and to help find the optimal path for the edits.
# - Understand how dynamic programming works
#
#
# Similar systems are used everywhere.
# - For example, if you type in the word **"I am lerningg"**, chances are very high that you meant to write **"learning"**

# %% [markdown]
# # Part 1: Data Preprocessing

# %%
import re
from collections import Counter
import numpy as np
import pandas as pd

# %%
def process_data(file_name):
    """
    Input: 
        A file_name which is found in your current directory. You just have to read it in. 
    Output: 
        words: a list containing all the words in the corpus (text file you read) in lower case. 
    """
    words = [] # return this variable correctly

    with open(file_name, encoding='UTF-8') as f:
        contents3 = f.read()

    contents2 = contents3.lower()
    words = re.findall(r'\w+',contents2)
    
    return words

# %%
word_l = process_data('sapiens.txt')
vocab = set(word_l)  # this will be new vocabulary
print(f"The first ten words in the text are: \n{word_l[0:10]}")
print(f"There are {len(vocab)} unique words in the vocabulary.")
# Out:
# The first ten words in the text are:
# ['kolektif', 'kitap', '63', 'i', 'nceleme', '8', 'hayvanlardan', 'tanrılara', 'sapiens', 'i']
# There are 26690 unique words in the vocabulary.

# %%
def get_count(word_l):
    '''
    Input:
        word_l: a set of words representing the corpus. 
    Output:
        word_count_dict: The wordcount dictionary where key is the word and value is its frequency.
    '''
    
    word_count_dict = {}  # fill this with word counts
    word_count_dict = Counter(word_l)

    return word_count_dict

# %%
word_count_dict = get_count(word_l)
print(f"There are {len(word_count_dict)} key values pairs")
print(f"The count for the word 'thee' is {word_count_dict.get('insan',0)}")
# Out:
# There are 26690 key values pairs
# The count for the word 'thee' is 326

# %%
def get_probs(word_count_dict):
    '''
    Input:
        word_count_dict: The wordcount dictionary where key is the word and value is its frequency.
    Output:
        probs: A dictionary where keys are the words and the values are the probability that a word will occur. 
    '''
    probs = {}  # return this variable correctly

    for i in word_count_dict.keys():
        probs[i] = word_count_dict[i] / sum(word_count_dict.values())

    return probs

# %%
probs = get_probs(word_count_dict)
print(f"Length of probs is {len(probs)}")
print(f"P('insan') is {probs['insan']:.4f}")
# Out:
# Length of probs is 26690
# P('insan') is 0.0029

# %% [markdown]
# # Part 2: String Manipulations
#
# Now, I have computed $P(w_i)$ for all the words in the corpus, you will write a few functions to manipulate strings so that you can edit the erroneous strings and return the right spellings of the words. In this section, I implemented four functions:
#
# * `delete_letter`: given a word, it returns all the possible strings that have **one character removed**.
# * `switch_letter`: given a word, it returns all the possible strings that have **two adjacent letters switched**.
# * `replace_letter`: given a word, it returns all the possible strings that have **one character replaced by another different letter**.
# * `insert_letter`: given a word, it returns all the possible strings that have an **additional character inserted**.

# %%
def delete_letter(word, verbose=False):
    '''
    Input:
        word: the string/word for which you will generate all possible words 
                in the vocabulary which have 1 missing character
    Output:
        delete_l: a list of all possible strings obtained by deleting 1 character from word
    '''
    
    delete_l = []
    split_l = []

    split_l = [(word[:i], word[i:]) for i in range(len(word))]
    
    delete_l = [left+right[1:] for left,right in split_l if right ]

    if verbose: print(f"input word {word}, \nsplit_l = {split_l}, \ndelete_l = {delete_l}")

    return delete_l

# %%
delete_word_l = delete_letter(word="insan",
                        verbose=True)
# Out:
# input word insan,
# split_l = [('', 'insan'), ('i', 'nsan'), ('in', 'san'), ('ins', 'an'), ('insa', 'n')],
# delete_l = ['nsan', 'isan', 'inan', 'insn', 'insa']

# %%
def switch_letter(word, verbose=False):
    '''
    Input:
        word: input string
     Output:
        switches: a list of all possible strings with one adjacent charater switched
    ''' 
    
    switch_l = []
    split_l = []
    
    split_l = [(word[:i],word[i:])for i in range(len(word))]
    switch_l =[left[:-1] + right[0] + left[-1] + right[1:]  for left,right in split_l if left]
    
    if verbose: print(f"Input word = {word} \nsplit_l = {split_l} \nswitch_l = {switch_l}") 

    return switch_l

# %%
switch_word_l = switch_letter(word="insan",
                         verbose=True)
# Out:
# Input word = insan
# split_l = [('', 'insan'), ('i', 'nsan'), ('in', 'san'), ('ins', 'an'), ('insa', 'n')]
# switch_l = ['nisan', 'isnan', 'inasn', 'insna']

# %%
def replace_letter(word, verbose=False):
    '''
    Input:
        word: the input string/word 
    Output:
        replaces: a list of all possible strings where we replaced one letter from the original word. 
    ''' 
    
    letters = 'abcdefghijklmnopqrstuvwxyz'
    replace_l = []
    split_l = []
    
    ### START CODE HERE ###
    split_l = [(word[:i], word[i:]) for i in range(len(word))] 
    replace_ll = [left + c + right[1:] for left, right in split_l for c in letters if not (left + c + right[1:]==word)]
    replace_set = set(replace_ll)
    ### END CODE HERE ###
    
    # turn the set back into a list and sort it, for easier viewing
    replace_l = sorted(list(replace_set))
    
    if verbose: print(f"Input word = {word} \nsplit_l = {split_l} \nreplace_l {replace_l}")   
    
    return replace_l

# %%
replace_l = replace_letter(word='insan',
                              verbose=True)
# Out:
# Input word = insan
# split_l = [('', 'insan'), ('i', 'nsan'), ('in', 'san'), ('ins', 'an'), ('insa', 'n')]
# replace_l ['ansan', 'bnsan', 'cnsan', 'dnsan', 'ensan', 'fnsan', 'gnsan', 'hnsan', 'iasan', 'ibsan', 'icsan', 'idsan', 'iesan', 'ifsan', 'igsan', 'ihsan', 'iisan', 'ijsan', 'iksan', 'ilsan', 'imsan', 'inaan', 'inban', 'incan', 'indan', 'inean', 'infan', 'ingan', 'inhan', 'inian', 'injan', 'inkan', 'inlan', 'inman', 'innan', 'inoan', 'inpan', 'inqan', 'inran', 'insaa', 'insab', 'insac', 'insad', 'insae', 'insaf', 'insag', 'insah', 'insai', 'insaj', 'insak', 'insal', 'insam', 'insao', 'insap', 'insaq', 'insar', 'insas', 'insat', 'insau', 'insav', 'insaw', 'insax', 'insay', 'insaz', 'insbn', 'inscn', 'insdn', 'insen', 'insfn', 'insgn', 'inshn', 'insin', 'insjn', 'inskn', 'insln', 'insmn', 'insnn', 'inson', 'inspn', 'insqn', 'insrn', 'inssn', 'instn', 'insun', 'insvn', 'inswn', 'insxn', 'insyn', 'inszn', 'intan', 'inuan', 'invan', 'inwan', 'inxan', 'inyan', 'inzan', 'iosan', 'ipsan', 'iqsan', 'irsan', 'issan', 'itsan', 'iusan', 'ivsan', 'iwsan', 'ixsan', 'iysan', 'izsan', 'jnsan', 'knsan', 'lnsan', 'mnsan', 'nnsan', 'onsan', 'pnsan', 'qnsan', 'rnsan', 'snsan', 'tnsan', 'unsan', 'vnsan', 'wnsan', 'xnsan', 'ynsan', 'znsan']

# %%
def insert_letter(word, verbose=False):
    '''
    Input:
        word: the input string/word 
    Output:
        inserts: a set of all possible strings with one new letter inserted at every offset
    ''' 
    letters = 'abcdefghijklmnopqrstuvwxyz'
    insert_l = []
    split_l = []
    
    split_l = [(word[:i],word[i:]) for i in range(len(word) + 1)]
    insert_l = [left + c + right for left,right in split_l for c in letters]
   
    if verbose: print(f"Input word {word} \nsplit_l = {split_l} \ninsert_l = {insert_l}")
    
    return insert_l

# %%
insert_l = insert_letter('insan', True)
print(f"Number of strings output by insert_letter('at') is {len(insert_l)}")
# Out:
# Input word insan
# split_l = [('', 'insan'), ('i', 'nsan'), ('in', 'san'), ('ins', 'an'), ('insa', 'n'), ('insan', '')]
# insert_l = ['ainsan', 'binsan', 'cinsan', 'dinsan', 'einsan', 'finsan', 'ginsan', 'hinsan', 'iinsan', 'jinsan', 'kinsan', 'linsan', 'minsan', 'ninsan', 'oinsan', 'pinsan', 'qinsan', 'rinsan', 'sinsan', 'tinsan', 'uinsan', 'vinsan', 'winsan', 'xinsan', 'yinsan', 'zinsan', 'iansan', 'ibnsan', 'icnsan', 'idnsan', 'iensan', 'ifnsan', 'ignsan', 'ihnsan', 'iinsan', 'ijnsan', 'iknsan', 'ilnsan', 'imnsan', 'innsan', 'ionsan', 'ipnsan', 'iqnsan', 'irnsan', 'isnsan', 'itnsan', 'iunsan', 'ivnsan', 'iwnsan', 'ixnsan', 'iynsan', 'iznsan', 'inasan', 'inbsan', 'incsan', 'indsan', 'inesan', 'infsan', 'ingsan', 'inhsan', 'inisan', 'injsan', 'inksan', 'inlsan', 'inmsan', 'innsan', 'inosan', 'inpsan', 'inqsan', 'inrsan', 'inssan', 'intsan', 'inusan', 'invsan', 'inwsan', 'inxsan', 'inysan', 'inzsan', 'insaan', 'insban', 'inscan', 'insdan', 'insean', 'insfan', 'insgan', 'inshan', 'insian', 'insjan', 'inskan', 'inslan', 'insman', 'insnan', 'insoan', 'inspan', 'insqan', 'insran', 'inssan', 'instan', 'insuan', 'insvan', 'inswan', 'insxan', 'insyan', 'inszan', 'insaan', 'insabn', 'insacn', 'insadn', 'insaen', 'insafn', 'insagn', 'insahn', 'insain', 'insajn', 'insakn', 'insaln', 'insamn', 'insann', 'insaon', 'insapn', 'insaqn', 'insarn', 'insasn', 'insatn', 'insaun', 'insavn', 'insawn', 'insaxn', 'insayn', 'insazn', 'insana', 'insanb', 'insanc', 'insand', 'insane', 'insanf', 'insang', 'insanh', 'insani', 'insanj', 'insank', 'insanl', 'insanm', 'insann', 'insano', 'insanp', 'insanq', 'insanr', 'insans', 'insant', 'insanu', 'insanv', 'insanw', 'insanx', 'insany', 'insanz']
# Number of strings output by insert_letter('at') is 156

# %%
def edit_one_letter(word, allow_switches = True):
    """
    Input:
        word: the string/word for which we will generate all possible wordsthat are one edit away.
    Output:
        edit_one_set: a set of words with one possible edit. Please return a set. and not a list.
    """
    
    edit_one_set = set()
    one_list = insert_letter(word) + delete_letter(word) + replace_letter(word)
    if allow_switches:
        edit_one_set = set(switch_letter(word) + one_list)
    else:
        edit_one_set = set(one_list)

    return edit_one_set

# %%
tmp_word = "insan"
tmp_edit_one_set = edit_one_letter(tmp_word)
# turn this into a list to sort it, in order to view it
tmp_edit_one_l = sorted(list(tmp_edit_one_set))

print(f"input word {tmp_word} \nedit_one_l \n{tmp_edit_one_l}\n")
print(f"The type of the returned object should be a set {type(tmp_edit_one_set)}")
print(f"Number of outputs from edit_one_letter('at') is {len(edit_one_letter('at'))}")
# Out:
# input word insan
# edit_one_l
# ['ainsan', 'ansan', 'binsan', 'bnsan', 'cinsan', 'cnsan', 'dinsan', 'dnsan', 'einsan', 'ensan', 'finsan', 'fnsan', 'ginsan', 'gnsan', 'hinsan', 'hnsan', 'iansan', 'iasan', 'ibnsan', 'ibsan', 'icnsan', 'icsan', 'idnsan', 'idsan', 'iensan', 'iesan', 'ifnsan', 'ifsan', 'ignsan', 'igsan', 'ihnsan', 'ihsan', 'iinsan', 'iisan', 'ijnsan', 'ijsan', 'iknsan', 'iksan', 'ilnsan', 'ilsan', 'imnsan', 'imsan', 'inaan', 'inan', 'inasan', 'inasn', 'inban', 'inbsan', 'incan', 'incsan', 'indan', 'indsan', 'inean', 'inesan', 'infan', 'infsan', 'ingan', 'ingsan', 'inhan', 'inhsan', 'inian', 'inisan', 'injan', 'injsan', 'inkan', 'inksan', 'inlan', 'inlsan', 'inman', 'inmsan', 'innan', 'innsan', 'inoan', 'inosan', 'inpan', 'inpsan', 'inqan', 'inqsan', 'inran', 'inrsan', 'insa', 'insaa', 'insaan', 'insab', 'insabn', 'insac', 'insacn', 'insad', 'insadn', 'insae', 'insaen', 'insaf', 'insafn', 'insag', 'insagn', 'insah', 'insahn', 'insai', 'insain', 'insaj', 'insajn', 'insak', 'insakn', 'insal', 'insaln', 'insam', 'insamn', 'insana', 'insanb', 'insanc', 'insand', 'insane', 'insanf', 'insang', 'insanh', 'insani', 'insanj', 'insank', 'insanl', 'insanm', 'insann', 'insano', 'insanp', 'insanq', 'insanr', 'insans', 'insant', 'insanu', 'insanv', 'insanw', 'insanx', 'insany', 'insanz', 'insao', 'insaon', 'insap', 'insapn', 'insaq', 'insaqn', 'insar', 'insarn', 'insas', 'insasn', 'insat', 'insatn', 'insau', 'insaun', 'insav', 'insavn', 'insaw', 'insawn', 'insax', 'insaxn', 'insay', 'insayn', 'insaz', 'insazn', 'insban', 'insbn', 'inscan', 'inscn', 'insdan', 'insdn', 'insean', 'insen', 'insfan', 'insfn', 'insgan', 'insgn', 'inshan', 'inshn', 'insian', 'insin', 'insjan', 'insjn', 'inskan', 'inskn', 'inslan', 'insln', 'insman', 'insmn', 'insn', 'insna', 'insnan', 'insnn', 'insoan', 'inson', 'inspan', 'inspn', 'insqan', 'insqn', 'insran', 'insrn', 'inssan', 'inssn', 'instan', 'instn', 'insuan', 'insun', 'insvan', 'insvn', 'inswan', 'inswn', 'insxan', 'insxn', 'insyan', 'insyn', 'inszan', 'inszn', 'intan', 'intsan', 'inuan', 'inusan', 'invan', 'invsan', 'inwan', 'inwsan', 'inxan', 'inxsan', 'inyan', 'inysan', 'inzan', 'inzsan', 'ionsan', 'iosan', 'ipnsan', 'ipsan', 'iqnsan', 'iqsan', 'irnsan', 'irsan', 'isan', 'isnan', 'isnsan', 'issan', 'itnsan', 'itsan', 'iunsan', 'iusan', 'ivnsan', 'ivsan', 'iwnsan', 'iwsan', 'ixnsan', 'ixsan', 'iynsan', 'iysan', 'iznsan', 'izsan', 'jinsan', 'jnsan', 'kinsan', 'knsan', 'linsan', 'lnsan', 'minsan', 'mnsan', 'ninsan', 'nisan', 'nnsan', 'nsan', 'oinsan', 'onsan', 'pinsan', 'pnsan', 'qinsan', 'qnsan', 'rinsan', 'rnsan', 'sinsan', 'snsan', 'tinsan', 'tnsan', 'uinsan', 'unsan', 'vinsan', 'vnsan', 'winsan', 'wnsan', 'xinsan', 'xnsan', 'yinsan', 'ynsan', 'zinsan', 'znsan']
#
# The type of the returned object should be a set <class 'set'>
# Number of outputs from edit_one_letter('at') is 129

# %%
def edit_two_letters(word, allow_switches = True):
    '''
    Input:
        word: the input string/word 
    Output:
        edit_two_set: a set of strings with all possible two edits
    '''    
    edit_two_set = set()

    for new_word in edit_one_letter(word):
        edit_two_set = edit_two_set|edit_one_letter(new_word, allow_switches=allow_switches)
   
    return edit_two_set

# %%
tmp_edit_two_set = edit_two_letters("insan")
tmp_edit_two_l = sorted(list(tmp_edit_two_set))
print(f"Number of strings with edit distance of two: {len(tmp_edit_two_l)}")
print(f"First 10 strings {tmp_edit_two_l[:10]}")
print(f"Last 10 strings {tmp_edit_two_l[-10:]}")
print(f"The data type of the returned object should be a set {type(tmp_edit_two_set)}")
print(f"Number of strings that are 2 edit distances from 'at' is {len(edit_two_letters('at'))}")
# Out:
# Number of strings with edit distance of two: 36859
# First 10 strings ['aainsan', 'aansan', 'aasan', 'abinsan', 'abnsan', 'absan', 'acinsan', 'acnsan', 'acsan', 'adinsan']
# Last 10 strings ['zwsan', 'zxinsan', 'zxnsan', 'zxsan', 'zyinsan', 'zynsan', 'zysan', 'zzinsan', 'zznsan', 'zzsan']
# The data type of the returned object should be a set <class 'set'>
# Number of strings that are 2 edit distances from 'at' is 7154

# %%
def get_corrections(word, probs, vocab, n=2, verbose = False):
    '''
    Input: 
        word: a user entered string to check for suggestions
        probs: a dictionary that maps each word to its probability in the corpus
        vocab: a set containing all the vocabulary
        n: number of possible word corrections you want returned in the dictionary
    Output: 
        n_best: a list of tuples with the most probable n corrected words and their probabilities.
    '''
    
    suggestions = []
    n_best = []

    if word not in vocab:
        edit_one = edit_one_letter(word)
        edit_one_vocab =edit_one.intersection(vocab)
        edit_two = edit_two_letters(word)
        edit_two_vocab = edit_two.intersection(vocab)
        suggestions = list(edit_one_vocab) or list(edit_two_vocab)
        prob_suggestions = [probs[i] for i in suggestions]
        n_best_inx = np.argsort(prob_suggestions)[-3:][::-1]#n olacak
        n_best = [(suggestions[i],prob_suggestions[i]) for i in n_best_inx]
    else:
        n_best = [(word,1)]

    if verbose: print("entered word = ", word, "\nsuggestions = ", suggestions)

    return n_best

# %%
# Testing implementation - feel free to try other words in my word
my_word = 'insson' 
tmp_corrections = get_corrections(my_word, probs, vocab, 2, verbose=True) # keep verbose=True
for i, word_prob in enumerate(tmp_corrections):
    print(f"word {i}: {word_prob[0]}, probability {word_prob[1]:.6f}")

print(f"data type of corrections {type(tmp_corrections)}")
# Out:
# entered word =  insson
# suggestions =  ['insan', 'sasson']
# word 0: insan, probability 0.002874
# word 1: sasson, probability 0.000026
# data type of corrections <class 'list'>

# %% [markdown]
# # Part 3: Minimum Edit Distance

# %%
def min_edit_distance(source, target, ins_cost = 1, del_cost = 1, rep_cost = 2):
    '''
    Input: 
        source: a string corresponding to the string you are starting with
        target: a string corresponding to the string you want to end with
        ins_cost: an integer setting the insert cost
        del_cost: an integer setting the delete cost
        rep_cost: an integer setting the replace cost
    Output:
        D: a matrix of len(source)+1 by len(target)+1 containing minimum edit distances
        med: the minimum edit distance (med) required to convert the source string to the target
    '''
   
    m = len(source) 
    n = len(target) 
    
    D = np.zeros((m+1, n+1), dtype=int)    

    for row in range(1,m+1): 
        D[row,0] = D[row-1,0] + 1
        
    for col in range(1,n+1): 
        D[0,col] = D[0,col-1] + 1
        
    for row in range(1,m+1): 
        
        for col in range(1,n+1):
            
            r_cost = rep_cost          
                
            if source[row-1] == target[col-1]:
               
                r_cost = 0                
            
            D[row,col] = min(D[row-1,col]+del_cost,D[row,col-1]+ins_cost, D[row-1,col-1]+r_cost)
    
    med = D[m,n]
    
    return D, med

# %%
source =  'insson'
target = 'insan '
matrix, min_edits = min_edit_distance(source, target)
print("minimum edits: ",min_edits, "\n")
idx = list('#' + source)
cols = list('#' + target)
df = pd.DataFrame(matrix, index=idx, columns= cols)
print(df)
# Out:
# minimum edits:  4
#
#    #  i  n  s  a  n
# #  0  1  2  3  4  5  6
# i  1  0  1  2  3  4  5
# n  2  1  0  1  2  3  4
# s  3  2  1  0  1  2  3
# s  4  3  2  1  2  3  4
# o  5  4  3  2  3  4  5
# n  6  5  4  3  4  3  4

# %%
source = "inson"
targets = edit_one_letter(source,allow_switches = False)  #disable switches since min_edit_distance does not include them
for t in targets:
    _, min_edits = min_edit_distance(source, t,1,1,1)  # set ins, del, sub costs all to one
    if min_edits != 1: print(source, t, min_edits)

# %%
source = "inson"
targets = edit_two_letters(source,allow_switches = False) #disable switches since min_edit_distance does not include them
for t in targets:
    _, min_edits = min_edit_distance(source, t,1,1,1)  # set ins, del, sub costs all to one
    if min_edits != 2 and min_edits != 1: print(source, t, min_edits)
# Out:
# inson inosne 3
# inson nisrn 3
# inson hsnon 3
# inson xnosn 3
# inson nistn 3
# inson inqno 3
# inson iwnosn 3
# inson uinosn 3
# inson isnkn 3
# inson gnsno 3
# inson iqosn 3
# inson isnor 3
# inson insnso 3
# inson nision 3
# inson isnoy 3
# inson nisyn 3
# inson izsno 3
# inson isfnon 3
# inson inocsn 3
# inson ysnon 3
# inson nisogn 3
# inson inmsno 3
# inson nisoin 3
# inson ssnon 3
# inson isdnon 3
# inson irnsno 3
# inson linsno 3
# inson nisonf 3
# inson cnsno 3
# inson isnod 3
# inson niswn 3
# inson naison 3
# inson isnosn 3
# inson niston 3
# inson niion 3
# inson wisnon 3
# inson inorsn 3
# inson isnxn 3
# inson isnyn 3
# inson ihnsno 3
# inson ibnosn 3
# inson snsno 3
# inson insnbo 3
# inson insnto 3
# inson nisow 3
# inson inolsn 3
# inson imosn 3
# inson isnono 3
# inson yisnon 3
# inson inose 3
# inson isnoqn 3
# inson ixnosn 3
# inson itosn 3
# inson lsnon 3
# inson nisoh 3
# inson iqnsno 3
# inson isnonu 3
# inson nisocn 3
# inson kisnon 3
# inson sisnon 3
# inson tnosn 3
# inson inrsno 3
# inson tinosn 3
# inson nnosn 3
# inson knosn 3
# inson nmison 3
# inson inano 3
# inson isnopn 3
# inson nisnon 3
# inson inpsno 3
# inson nizon 3
# inson isnobn 3
# inson inosnr 3
# inson nisron 3
# inson iusno 3
# inson tsnon 3
# inson inosnp 3
# inson iqnosn 3
# inson nisonl 3
# inson igosn 3
# inson nimon 3
# inson inozsn 3
# inson iuosn 3
# inson nisopn 3
# inson isnoa 3
# inson nisok 3
# inson isnohn 3
# inson inosnj 3
# inson isnop 3
# inson idsno 3
# inson inogsn 3
# inson isnonn 3
# inson iznosn 3
# inson ifnsno 3
# inson isnin 3
# inson inosnu 3
# inson nivon 3
# inson ninosn 3
# inson ncison 3
# inson insngo 3
# inson icnsno 3
# inson iwosn 3
# inson niwon 3
# inson inysno 3
# inson isnoh 3
# inson inosnt 3
# inson pinosn 3
# inson nijon 3
# inson ihsno 3
# inson asnon 3
# inson nqison 3
# inson insnjo 3
# inson nisovn 3
# inson isnoun 3
# inson inxno 3
# inson isnoxn 3
# inson ynosn 3
# inson isnorn 3
# inson iosno 3
# inson intsno 3
# inson bnsno 3
# inson invsno 3
# inson niskon 3
# inson igsno 3
# inson nisoyn 3
# inson ksnon 3
# inson inksno 3
# inson znsno 3
# inson ainsno 3
# inson irsno 3
# inson inhno 3
# inson inonsn 3
# inson nisom 3
# inson innsno 3
# inson uinsno 3
# inson isjnon 3
# inson nisorn 3
# inson ieosn 3
# inson ifsno 3
# inson inoesn 3
# inson nisotn 3
# inson vnsno 3
# inson hnosn 3
# inson einsno 3
# inson isnoe 3
# inson nidon 3
# inson ainosn 3
# inson ijnsno 3
# inson nisxon 3
# inson isnob 3
# inson inmno 3
# inson inosc 3
# inson nisont 3
# inson iinsno 3
# inson ginosn 3
# inson iesno 3
# inson nisox 3
# inson inoxsn 3
# inson insnuo 3
# inson nisomn 3
# inson isnwn 3
# inson snosn 3
# inson inosng 3
# inson onsno 3
# inson isynon 3
# inson isnonl 3
# inson ismnon 3
# inson inosg 3
# inson insnwo 3
# inson imnsno 3
# inson isnog 3
# inson rinosn 3
# inson itnosn 3
# inson isbnon 3
# inson isnfn 3
# inson inofsn 3
# inson finsno 3
# inson isnvn 3
# inson isnoq 3
# inson finosn 3
# inson nisonp 3
# inson nilon 3
# inson nislon 3
# inson isqnon 3
# inson yinsno 3
# inson inohsn 3
# inson isnow 3
# inson ifosn 3
# inson isnokn 3
# inson dnosn 3
# inson nxison 3
# inson inosy 3
# inson anosn 3
# inson inosnv 3
# inson nispn 3
# inson nvison 3
# inson icosn 3
# inson isnoni 3
# inson inosv 3
# inson imsno 3
# inson nisonq 3
# inson nixon 3
# inson dinsno 3
# inson ilnsno 3
# inson lnsno 3
# inson inosnz 3
# inson ipnsno 3
# inson bsnon 3
# inson ipnosn 3
# inson isenon 3
# inson isnogn 3
# inson hisnon 3
# inson nisonj 3
# inson npison 3
# inson nisoon 3
# inson nisdon 3
# inson inosna 3
# inson pnosn 3
# inson niqon 3
# inson nisonz 3
# inson ivsno 3
# inson nisaon 3
# inson xnsno 3
# inson nisoo 3
# inson nisbn 3
# inson sinosn 3
# inson isnun 3
# inson ninsno 3
# inson idosn 3
# inson injno 3
# inson nisor 3
# inson nikon 3
# inson nisin 3
# inson isnoz 3
# inson jsnon 3
# inson inhsno 3
# inson nrison 3
# inson nisol 3
# inson inoysn 3
# inson inomsn 3
# inson isnrn 3
# inson nihon 3
# inson nisoe 3
# inson ionosn 3
# inson nisod 3
# inson ihosn 3
# inson insndo 3
# inson ionsno 3
# inson nyison 3
# inson vsnon 3
# inson nisosn 3
# inson isnonh 3
# inson nisonm 3
# inson isnen 3
# inson vnosn 3
# inson nigon 3
# inson onosn 3
# inson iaosn 3
# inson neison 3
# inson ivnosn 3
# inson wnosn 3
# inson ibsno 3
# inson inosu 3
# inson inosnx 3
# inson istnon 3
# inson winosn 3
# inson isanon 3
# inson inosl 3
# inson xsnon 3
# inson iknosn 3
# inson inosf 3
# inson fsnon 3
# inson nisono 3
# inson unosn 3
# inson ivosn 3
# inson inost 3
# inson nsno 3
# inson enosn 3
# inson isinon 3
# inson nisoan 3
# inson isnoc 3
# inson dsnon 3
# inson niron 3
# inson binosn 3
# inson niscon 3
# inson nispon 3
# inson isnong 3
# inson cinosn 3
# inson xinsno 3
# inson isnonp 3
# inson indno 3
# inson inoss 3
# inson nisobn 3
# inson isnoo 3
# inson isnona 3
# inson isnoan 3
# inson kinosn 3
# inson nismn 3
# inson inlsno 3
# inson inxsno 3
# inson uisnon 3
# inson ixsno 3
# inson isnonm 3
# inson ineno 3
# inson isxnon 3
# inson ioosn 3
# inson isnonx 3
# inson indsno 3
# inson ingsno 3
# inson fisnon 3
# inson isnln 3
# inson rnsno 3
# inson insnfo 3
# inson ensno 3
# inson qisnon 3
# inson infno 3
# inson inosns 3
# inson insnvo 3
# inson isnoin 3
# inson iyosn 3
# inson isnotn 3
# inson insnro 3
# inson eisnon 3
# inson nisonw 3
# inson qnsno 3
# inson nisoq 3
# inson jisnon 3
# inson inwsno 3
# inson minsno 3
# inson ihnosn 3
# inson isnok 3
# inson bisnon 3
# inson nisoqn 3
# inson isnmn 3
# inson nisoun 3
# inson niswon 3
# inson cnosn 3
# inson nisoy 3
# inson isunon 3
# inson itnsno 3
# inson ianosn 3
# inson zinsno 3
# inson hinsno 3
# inson nbison 3
# inson isnonj 3
# inson niscn 3
# inson iwsno 3
# inson isnonb 3
# inson rnosn 3
# inson ntison 3
# inson aisnon 3
# inson inotsn 3
# inson niyon 3
# inson invno 3
# inson intno 3
# inson isnont 3
# inson nisoz 3
# inson insnao 3
# inson nisqn 3
# inson isnoj 3
# inson wnsno 3
# inson zsnon 3
# inson nnsno 3
# inson niuon 3
# inson isnoln 3
# inson nhison 3
# inson inosnl 3
# inson isncn 3
# inson nisdn 3
# inson psnon 3
# inson nisonk 3
# inson unsno 3
# inson qnosn 3
# inson niso 3
# inson nisonv 3
# inson inosq 3
# inson isvnon 3
# inson ilosn 3
# inson nisoc 3
# inson inyno 3
# inson isno 3
# inson nisond 3
# inson inosnm 3
# inson inosnq 3
# inson isnou 3
# inson nuison 3
# inson isnozn 3
# inson nisqon 3
# inson rsnon 3
# inson isnond 3
# inson oinsno 3
# inson nisoln 3
# inson nisonx 3
# inson tisnon 3
# inson nisojn 3
# inson njison 3
# inson ibnsno 3
# inson inoasn 3
# inson inisno 3
# inson isznon 3
# inson nlison 3
# inson cisnon 3
# inson inopsn 3
# inson isnol 3
# inson inosm 3
# inson pisnon 3
# inson inesno 3
# inson ipsno 3
# inson inson 0
# inson icsno 3
# inson iisno 3
# inson xinosn 3
# inson dnsno 3
# inson inosnf 3
# inson iqsno 3
# inson linosn 3
# inson isnoi 3
# inson msnon 3
# inson isnomn 3
# inson ignosn 3
# inson nisony 3
# inson minosn 3
# inson oisnon 3
# inson icnosn 3
# inson inosx 3
# inson bnosn 3
# inson idnsno 3
# inson cinsno 3
# inson inowsn 3
# inson rinsno 3
# inson inosnb 3
# inson ginsno 3
# inson inosnd 3
# inson isgnon 3
# inson nisjon 3
# inson inosa 3
# inson zinosn 3
# inson nisodn 3
# inson winsno 3
# inson ndison 3
# inson fnosn 3
# inson insnxo 3
# inson innno 3
# inson nishon 3
# inson einosn 3
# inson nisoxn 3
# inson inousn 3
# inson isnot 3
# inson iansno 3
# inson noison 3
# inson pnsno 3
# inson hnsno 3
# inson isnhn 3
# inson isnnn 3
# inson inqsno 3
# inson visnon 3
# inson nisun 3
# inson nisfn 3
# inson irosn 3
# inson ynsno 3
# inson isnonv 3
# inson ngison 3
# inson inoksn 3
# inson binsno 3
# inson issno 3
# inson insnmo 3
# inson isnovn 3
# inson isnoen 3
# inson nismon 3
# inson nisozn 3
# inson inobsn 3
# inson islnon 3
# inson niton 3
# inson nisgon 3
# inson nwison 3
# inson isnqn 3
# inson infsno 3
# inson ilsno 3
# inson isnonr 3
# inson isnonk 3
# inson ansno 3
# inson insnco 3
# inson jnsno 3
# inson inbsno 3
# inson isnjn 3
# inson mnsno 3
# inson nisofn 3
# inson inosh 3
# inson iysno 3
# inson isnpn 3
# inson jinsno 3
# inson isngn 3
# inson nsison 3
# inson nibon 3
# inson yinosn 3
# inson mnosn 3
# inson jnosn 3
# inson misnon 3
# inson jinosn 3
# inson inrno 3
# inson znosn 3
# inson ijosn 3
# inson nisfon 3
# inson lnosn 3
# inson nisnn 3
# inson knsno 3
# inson qinsno 3
# inson inoqsn 3
# inson nisot 3
# inson ignsno 3
# inson ispnon 3
# inson inojsn 3
# inson nosn 3
# inson nisokn 3
# inson isnone 3
# inson isnox 3
# inson itsno 3
# inson inosw 3
# inson incsno 3
# inson inkno 3
# inson nisn 3
# inson disnon 3
# inson esnon 3
# inson xisnon 3
# inson nisone 3
# inson isnos 3
# inson wsnon 3
# inson nisjn 3
# inson isntn 3
# inson vinsno 3
# inson pinsno 3
# inson isnocn 3
# inson inbno 3
# inson ijnosn 3
# inson isknon 3
# inson nissn 3
# inson nisonh 3
# inson nisonb 3
# inson isnonz 3
# inson ikosn 3
# inson insnqo 3
# inson vinosn 3
# inson inzno 3
# inson nisoa 3
# inson isnony 3
# inson isnonf 3
# inson inosp 3
# inson inosz 3
# inson insnpo 3
# inson isnzn 3
# inson inosnh 3
# inson niaon 3
# inson gisnon 3
# inson inosnk 3
# inson inosny 3
# inson isonon 3
# inson iensno 3
# inson zisnon 3
# inson inosb 3
# inson nieon 3
# inson nisuon 3
# inson inzsno 3
# inson inodsn 3
# inson idnosn 3
# inson nisona 3
# inson ilnosn 3
# inson ienosn 3
# inson isnons 3
# inson ivnsno 3
# inson inosd 3
# inson inwno 3
# inson isnbn 3
# inson ibosn 3
# inson nisvon 3
# inson qinosn 3
# inson gsnon 3
# inson insnzo 3
# inson iznsno 3
# inson inosi 3
# inson nisou 3
# inson iunsno 3
# inson nisog 3
# inson nisong 3
# inson nisonn 3
# inson nisof 3
# inson isnof 3
# inson nisonr 3
# inson nisob 3
# inson isnonq 3
# inson isndn 3
# inson nipon 3
# inson inosr 3
# inson inlno 3
# inson nisbon 3
# inson nisons 3
# inson ixosn 3
# inson nicon 3
# inson nisown 3
# inson ingno 3
# inson niseon 3
# inson qsnon 3
# inson insnyo 3
# inson gnosn 3
# inson nisen 3
# inson incno 3
# inson nzison 3
# inson isnan 3
# inson sinsno 3
# inson isnoyn 3
# inson iynsno 3
# inson isnom 3
# inson iksno 3
# inson inasno 3
# inson isnonc 3
# inson nisoen 3
# inson irnosn 3
# inson isnov 3
# inson ijsno 3
# inson inosnc 3
# inson iwnsno 3
# inson isnonw 3
# inson kinsno 3
# inson inusno 3
# inson nisoi 3
# inson iinosn 3
# inson iiosn 3
# inson fnsno 3
# inson nisoni 3
# inson isnofn 3
# inson inosj 3
# inson iposn 3
# inson injsno 3
# inson isnodn 3
# inson izosn 3
# inson inosni 3
# inson insnio 3
# inson nisxn 3
# inson nishn 3
# inson nifon 3
# inson insnlo 3
# inson isnown 3
# inson osnon 3
# inson nkison 3
# inson nfison 3
# inson risnon 3
# inson inino 3
# inson iunosn 3
# inson dinosn 3
# inson ifnosn 3
# inson inosnw 3
# inson ishnon 3
# inson niszon 3
# inson nisov 3
# inson insnho 3
# inson iynosn 3
# inson tinsno 3
# inson nisonc 3
# inson nisoj 3
# inson insnko 3
# inson inuno 3
# inson inosk 3
# inson csnon 3
# inson nisop 3
# inson hinosn 3
# inson iasno 3
# inson insneo 3
# inson inovsn 3
# inson nisos 3
# inson nioon 3
# inson inosno 3
# inson nisln 3
# inson isrnon 3
# inson iknsno 3
# inson nisan 3
# inson iswnon 3
# inson nisonu 3
# inson nisohn 3
# inson isnsno 3
# inson usnon 3
# inson iscnon 3
# inson lisnon 3
# inson tnsno 3
# inson niskn 3
# inson ixnsno 3
# inson oinosn 3
# inson nisvn 3
# inson imnosn 3
# inson isnojn 3
# inson nisyon 3
# inson nisgn 3
# inson inoisn 3
# inson niszn 3
# inson inpno 3
